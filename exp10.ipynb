# %% [markdown]
# <a href="https://colab.research.google.com/github/Pravallikabesi/opencv-lab/blob/main/exp10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from google.colab import files
import matplotlib.pyplot as plt

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4ae8b8d7-d48d-4434-b174-d110b058ee7b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ae8b8d7-d48d-4434-b174-d110b058ee7b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = cv2.imread('apple.jpg')   # change filename
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=676x579>

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=676x579>

# %%
plt.title("Grayscale Histogram")
plt.xlabel("Pixel Intensity")
plt.ylabel("Frequency")

plt.hist(gray.ravel(), 256, [0,256])
plt.show()
# Out:
# /tmp/ipykernel_14255/3349579578.py:5: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(gray.ravel(), 256, [0,256])

# %%
colors = ('b', 'g', 'r')

for i, col in enumerate(colors):
    hist = cv2.calcHist([img], [i], None, [256], [0,256])
    plt.plot(hist, color=col)

plt.title("RGB Histogram")
plt.xlabel("Pixel Intensity")
plt.ylabel("Frequency")
plt.show()

# %%
equalized = cv2.equalizeHist(gray)
cv2_imshow(equalized)
# Out:
# <PIL.Image.Image image mode=L size=676x579>

# %%
plt.title("Equalized Histogram")
plt.hist(equalized.ravel(), 256, [0,256])
plt.show()
# Out:
# /tmp/ipykernel_14255/3551153603.py:2: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(equalized.ravel(), 256, [0,256])

# %%
cv2_imshow(gray)
cv2_imshow(equalized)
# Out:
# <PIL.Image.Image image mode=L size=676x579>
# <PIL.Image.Image image mode=L size=676x579>
